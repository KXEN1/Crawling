# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# -----------------------------
# 1. 브라우저 설정
# -----------------------------
options = Options()
# options.add_argument("--headless")  # 화면 안 띄우고 실행하려면 주석 해제
options.add_argument("--disable-gpu")
options.add_argument("start-maximized")
options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# -----------------------------
# 2. 사이트 접속
# -----------------------------
main_url = "https://contents.premium.naver.com/willam/william/contents/251122004412980pn"
driver.get(main_url)
print("여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...")
input()  # 사용자가 로그인 완료할 때까지 대기

time.sleep(2)  # 로그인 후 페이지 안정화

# -----------------------------
# 3. 로그인 후 바로 크롤링
# -----------------------------
elements = driver.find_elements(By.XPATH, '//span[starts-with(@id, "SE-")]')
results = [el.text.strip() for el in elements if el.text.strip()]

print(f"총 {len(results)}개의 span 텍스트 추출")
for r in results[:5]:  ################################ 샘플 출력
    print(r)

# -----------------------------
# 4. txt 파일로 저장
# -----------------------------
with open("extracted_spans.txt", "w", encoding="utf-8") as f:
    for line in results:
        f.write(line + "\n")

print("extracted_spans.txt 저장 완료")

driver.quit()
# Out:
# 여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...
# 총 77개의 span 텍스트 추출
# AI 민주주의! 인류의 마지막 정치 시스템 (+12)
# 와썹 윌리엄!🥭
# 지난 내용! 의식 자본주의 시대에 이어서
# AI 민주주의 인류의 마지막 정치 시스템에 대해 알려줄게!
# AI가 행정을 돕는다는 수준의 얘기가 아니라
# extracted_spans.txt 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# -----------------------------
# 1. 브라우저 설정
# -----------------------------
options = Options()
# options.add_argument("--headless")  # 화면 안 띄우고 실행하려면 주석 해제
options.add_argument("--disable-gpu")
options.add_argument("start-maximized")
options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# -----------------------------
# 2. 사이트 접속
# -----------------------------
main_url = "https://contents.premium.naver.com/willam/william/contents/251122004412980pn"
driver.get(main_url)
print("여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...")
input()  # 사용자가 로그인 완료할 때까지 대기

time.sleep(2)  # 로그인 후 페이지 안정화

# -----------------------------
# 3. 로그인 후 모든 SE- span 크롤링
# -----------------------------
elements = driver.find_elements(By.XPATH, '//span[starts-with(@id, "SE-")]')
results = [el.text.strip() for el in elements if el.text.strip()]

print(f"총 {len(results)}개의 span 텍스트 추출")

# -----------------------------
# 4. txt 파일로 저장
# -----------------------------
with open("extracted_spans.txt", "w", encoding="utf-8") as f:
    for line in results:
        f.write(line + "\n")

print("extracted_spans.txt 저장 완료")

driver.quit()
# Out:
# 여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...
# 총 77개의 span 텍스트 추출
# extracted_spans.txt 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# -----------------------------
# 1. 브라우저 설정
# -----------------------------
options = Options()
# options.add_argument("--headless")  # 화면 안 띄우고 실행하려면 주석 해제
options.add_argument("--disable-gpu")
options.add_argument("start-maximized")
options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# -----------------------------
# 2. 사이트 접속
# -----------------------------
main_url = "https://contents.premium.naver.com/willam/william/contents/251122002102901cl"
driver.get(main_url)
print("여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...")
input()  # 사용자가 로그인 완료할 때까지 대기

time.sleep(2)  # 로그인 후 페이지 안정화

# -----------------------------
# 3. 로그인 후 모든 SE- span 크롤링
# -----------------------------
elements = driver.find_elements(By.XPATH, '//span[starts-with(@id, "SE-")]')
results = [el.text.strip() for el in elements if el.text.strip()]

print(f"총 {len(results)}개의 span 텍스트 추출")

# -----------------------------
# 4. txt 파일로 저장
# -----------------------------
with open("extracted_spans1.txt", "w", encoding="utf-8") as f:
    for line in results:
        f.write(line + "\n")

print("extracted_spans.txt 저장 완료")

driver.quit()
# Out:
# 여기서 수동으로 로그인하세요. 로그인 후 Enter 키를 누르세요...
# 총 91개의 span 텍스트 추출
# extracted_spans.txt 저장 완료
